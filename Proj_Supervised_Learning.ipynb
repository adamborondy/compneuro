# %% [markdown]
# # MUW Neuroscience Seminar WS 23/24

# %% [markdown]
# ## Group Work: CAL MS21 Dataset

# %% [markdown]
# ## Project Goal

# %% [markdown]
# * Find out, if ML classifying can help in annotating the frames
# * A tab dataset of the mice coordinates is used
# * Several methods are tested against a dummy classifier as baseline

# %% [markdown]
# ## Literature

# %% [markdown]
# * S. Raschka & V. Mirjalili (2018) Datenvorverarbeitung. In: S. Raschka & V. Mirjalili. Machine Learning with Python and Scikit-earn and TensorFlow. S. 125-158 (Kapitel 4)
# * A. Famili et al (1997) Data Preprocessing and Intelligent Data Analysis. In: Intelligent Data Analysis Journal

# %% [markdown]
# ## 1 | Checking the data

# %% [markdown]
# Usage of several python libraries:
# - pandas, numpy
# - sklearn (scikit-learn)
#
# Dataset has been preprocessed separately, see parallel notebook.

# %%
# libraries

from sklearn.model_selection import cross_val_score, GridSearchCV
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1.1 Load the preprocessed dataset

# %% [markdown]
# In the dataset, there is one row/record for each frame containing the coordinates for each mouse bodypart as features.
# Statistical description displayed below and preview of data structure below.
#
# Data is already provided with train and test set.

# %% [markdown]
# ### Train Data

# %%
df_traindata = pd.read_csv('calms21_tab_data_train.csv') #check for the location of this file in your scenario
df_traindata.describe(include='all')
# Out:
#            Unnamed: 0                               sequence          frame  \
# count   507738.000000                                 507738  507738.000000
# unique            NaN                                     70            NaN
# top               NaN  task1/train/mouse001_task1_annotator1            NaN
# freq              NaN                                  21364            NaN
# mean    253868.500000                                    NaN    5694.667001
# std     146571.479826                                    NaN    4721.565589
# min          0.000000                                    NaN       0.000000
# 25%     126934.250000                                    NaN    1907.000000
# 50%     253868.500000                                    NaN    4374.000000
# 75%     380802.750000                                    NaN    8374.000000
# max     507737.000000                                    NaN   21363.000000
#
#                                             id          label      m1_x_nose  \
# count                                   507738  507738.000000  507738.000000
# unique                                  507738            NaN            NaN
# top     task1/train/mouse001_task1_annotator10            NaN            NaN
# freq                                         1            NaN            NaN
# mean                                       NaN       2.283170     498.981251
# std                                        NaN       0.972836     276.277653
# min                                        NaN       0.000000       0.000000
# 25%                                        NaN       1.000000     228.257655
# 50%                                        NaN       3.000000     503.394354
# 75%                                        NaN       3.000000     772.395674
# max                                        NaN       3.000000    1018.382385
#
#         m1_x_left_ear  m1_x_right_ear      m1_x_neck  m1_x_left_hip  ...  \
# count   507738.000000   507738.000000  507738.000000  507738.000000  ...
# unique            NaN             NaN            NaN            NaN  ...
# top               NaN             NaN            NaN            NaN  ...
# freq              NaN             NaN            NaN            NaN  ...
# mean       492.330323      498.293024     494.084736     485.628505  ...
# std        271.113108      272.273444     270.336755     265.768457  ...
# min         11.000000       32.000000      50.000000      11.000000  ...
# 25%        211.394948      215.392818     208.979365     216.654578  ...
# 50%        506.396939      505.847574     505.353545     502.474588  ...
# 75%        766.282243      775.290410     770.861516     744.781598  ...
# max        991.423523      991.013672     957.013672    1001.677673  ...
#
#         m2_x_right_hip  m2_x_tail_base      m2_y_nose  m2_y_left_ear  \
# count    507738.000000   507738.000000  507738.000000  507738.000000
# unique             NaN             NaN            NaN            NaN
# top                NaN             NaN            NaN            NaN
# freq               NaN             NaN            NaN            NaN
# mean        528.236839      526.511264     329.748869     332.345046
# std         276.762300      276.961196     130.553673     127.718573
# min          24.573660       12.000000       0.000000      10.000000
# 25%         239.425223      252.320353     220.132083     216.393679
# 50%         567.295091      564.528696     339.796427     350.923986
# 75%         796.357602      793.945117     442.006255     448.290094
# max         991.653851     1021.738464     569.487251     559.198379
#
#         m2_y_right_ear      m2_y_neck  m2_y_left_hip  m2_y_right_hip  \
# count    507738.000000  507738.000000  507738.000000   507738.000000
# unique             NaN            NaN            NaN             NaN
# top                NaN            NaN            NaN             NaN
# freq               NaN            NaN            NaN             NaN
# mean        329.677917     331.250143     335.278646      331.464391
# std         127.443641     125.596338     129.200753      129.353404
# min          19.000000      54.000000      23.000000       35.000000
# 25%         211.892586     211.618877     218.881433      211.845849
# 50%         343.092039     351.253515     358.677518      348.005436
# 75%         445.031193     450.738161     449.826209      443.011136
# max         564.111049     555.793921     559.419632      559.118217
#
#         m2_y_tail_base         attack
# count    507738.000000  507738.000000
# unique             NaN            NaN
# top                NaN            NaN
# freq               NaN            NaN
# mean        334.243921       0.027650
# std         134.293177       0.163968
# min          17.000000       0.000000
# 25%         208.543972       0.000000
# 50%         346.671118       0.000000
# 75%         462.314209       0.000000
# max         569.425169       1.000000
#
# [11 rows x 34 columns]

# %%
df_traindata.head(10)
# Out:
#    Unnamed: 0                               sequence  frame  \
# 0           0  task1/train/mouse001_task1_annotator1      0
# 1           1  task1/train/mouse001_task1_annotator1      1
# 2           2  task1/train/mouse001_task1_annotator1      2
# 3           3  task1/train/mouse001_task1_annotator1      3
# 4           4  task1/train/mouse001_task1_annotator1      4
# 5           5  task1/train/mouse001_task1_annotator1      5
# 6           6  task1/train/mouse001_task1_annotator1      6
# 7           7  task1/train/mouse001_task1_annotator1      7
# 8           8  task1/train/mouse001_task1_annotator1      8
# 9           9  task1/train/mouse001_task1_annotator1      9
#
#                                        id  label   m1_x_nose  m1_x_left_ear  \
# 0  task1/train/mouse001_task1_annotator10      3  831.659204     805.659204
# 1  task1/train/mouse001_task1_annotator11      1  833.050439     809.050439
# 2  task1/train/mouse001_task1_annotator12      1  838.718976     816.718976
# 3  task1/train/mouse001_task1_annotator13      1  826.757507     815.757507
# 4  task1/train/mouse001_task1_annotator14      1  822.045709     812.045709
# 5  task1/train/mouse001_task1_annotator15      1  818.778436     809.778436
# 6  task1/train/mouse001_task1_annotator16      1  806.099103     809.099103
# 7  task1/train/mouse001_task1_annotator17      1  803.039594     803.039594
# 8  task1/train/mouse001_task1_annotator18      1  800.631812     796.631812
# 9  task1/train/mouse001_task1_annotator19      1  800.814734     795.814734
#
#    m1_x_right_ear   m1_x_neck  m1_x_left_hip  ...  m2_x_right_hip  \
# 0      775.659204  780.659204     711.659204  ...      840.915924
# 1      778.050439  783.050439     723.050439  ...      846.907019
# 2      776.718976  787.718976     730.718976  ...      860.195703
# 3      774.757507  785.757507     743.757507  ...      856.788861
# 4      768.045709  779.045709     749.045709  ...      862.578644
# 5      761.778436  776.778436     741.778436  ...      857.949255
# 6      757.099103  776.099103     743.099103  ...      853.259283
# 7      752.039594  773.039594     733.039594  ...      850.518365
# 8      747.631812  765.631812     724.631812  ...      843.835266
# 9      746.814734  763.814734     726.814734  ...      840.120172
#
#    m2_x_tail_base   m2_y_nose  m2_y_left_ear  m2_y_right_ear   m2_y_neck  \
# 0      766.915924  253.216902     195.216902      193.216902  179.216902
# 1      766.907019  259.539977     204.539977      201.539977  188.539977
# 2      777.195703  256.902935     208.902935      205.902935  193.902935
# 3      786.788861  263.420539     206.420539      206.420539  193.420539
# 4      793.578644  263.366469     202.366469      201.366469  190.366469
# 5      791.949255  264.656704     198.656704      198.656704  189.656704
# 6      791.259283  263.464866     202.464866      198.464866  190.464866
# 7      790.518365  262.897428     198.897428      195.897428  187.897428
# 8      787.835266  263.704107     196.704107      194.704107  187.704107
# 9      787.120172  258.511888     194.511888      196.511888  186.511888
#
#    m2_y_left_hip  m2_y_right_hip  m2_y_tail_base  attack
# 0     152.216902      102.216902       97.216902       0
# 1     153.539977      105.539977       98.539977       0
# 2     150.902935      112.902935       99.902935       0
# 3     147.420539      113.420539       97.420539       0
# 4     143.366469      120.366469       95.366469       0
# 5     141.656704      116.656704       92.656704       0
# 6     142.464866      116.464866       93.464866       0
# 7     139.897428      114.897428       91.897428       0
# 8     139.704107      110.704107       90.704107       0
# 9     140.511888      109.511888       89.511888       0
#
# [10 rows x 34 columns]

# %% [markdown]
# The columns sequence and frame would actually not be meaningful data, we can drop them from the dataset or later not use in the feature list.

# %%
df_traindata = df_traindata.drop(columns=['Unnamed: 0', 'sequence', 'frame'])
df_traindata.head(1)
# Out:
#                                        id  label   m1_x_nose  m1_x_left_ear  \
# 0  task1/train/mouse001_task1_annotator10      3  831.659204     805.659204
#
#    m1_x_right_ear   m1_x_neck  m1_x_left_hip  m1_x_right_hip  m1_x_tail_base  \
# 0      775.659204  780.659204     711.659204      711.659204      643.659204
#
#     m1_y_nose  ...  m2_x_right_hip  m2_x_tail_base   m2_y_nose  m2_y_left_ear  \
# 0  202.914433  ...      840.915924      766.915924  253.216902     195.216902
#
#    m2_y_right_ear   m2_y_neck  m2_y_left_hip  m2_y_right_hip  m2_y_tail_base  \
# 0      193.216902  179.216902     152.216902      102.216902       97.216902
#
#    attack
# 0       0
#
# [1 rows x 31 columns]

# %%
df_traindata.describe(include='all')
# Out:
#                                             id          label      m1_x_nose  \
# count                                   507738  507738.000000  507738.000000
# unique                                  507738            NaN            NaN
# top     task1/train/mouse001_task1_annotator10            NaN            NaN
# freq                                         1            NaN            NaN
# mean                                       NaN       2.283170     498.981251
# std                                        NaN       0.972836     276.277653
# min                                        NaN       0.000000       0.000000
# 25%                                        NaN       1.000000     228.257655
# 50%                                        NaN       3.000000     503.394354
# 75%                                        NaN       3.000000     772.395674
# max                                        NaN       3.000000    1018.382385
#
#         m1_x_left_ear  m1_x_right_ear      m1_x_neck  m1_x_left_hip  \
# count   507738.000000   507738.000000  507738.000000  507738.000000
# unique            NaN             NaN            NaN            NaN
# top               NaN             NaN            NaN            NaN
# freq              NaN             NaN            NaN            NaN
# mean       492.330323      498.293024     494.084736     485.628505
# std        271.113108      272.273444     270.336755     265.768457
# min         11.000000       32.000000      50.000000      11.000000
# 25%        211.394948      215.392818     208.979365     216.654578
# 50%        506.396939      505.847574     505.353545     502.474588
# 75%        766.282243      775.290410     770.861516     744.781598
# max        991.423523      991.013672     957.013672    1001.677673
#
#         m1_x_right_hip  m1_x_tail_base      m1_y_nose  ...  m2_x_right_hip  \
# count    507738.000000   507738.000000  507738.000000  ...   507738.000000
# unique             NaN             NaN            NaN  ...             NaN
# top                NaN             NaN            NaN  ...             NaN
# freq               NaN             NaN            NaN  ...             NaN
# mean        494.056763      486.062736     316.323761  ...      528.236839
# std         266.441908      264.953242     126.095533  ...      276.762300
# min          38.490309        0.000000       6.000000  ...       24.573660
# 25%         223.686047      224.823090     208.243571  ...      239.425223
# 50%         505.035722      501.617735     312.861399  ...      567.295091
# 75%         749.365298      726.977702     427.954780  ...      796.357602
# max         996.415320      998.415320     569.333163  ...      991.653851
#
#         m2_x_tail_base      m2_y_nose  m2_y_left_ear  m2_y_right_ear  \
# count    507738.000000  507738.000000  507738.000000   507738.000000
# unique             NaN            NaN            NaN             NaN
# top                NaN            NaN            NaN             NaN
# freq               NaN            NaN            NaN             NaN
# mean        526.511264     329.748869     332.345046      329.677917
# std         276.961196     130.553673     127.718573      127.443641
# min          12.000000       0.000000      10.000000       19.000000
# 25%         252.320353     220.132083     216.393679      211.892586
# 50%         564.528696     339.796427     350.923986      343.092039
# 75%         793.945117     442.006255     448.290094      445.031193
# max        1021.738464     569.487251     559.198379      564.111049
#
#             m2_y_neck  m2_y_left_hip  m2_y_right_hip  m2_y_tail_base  \
# count   507738.000000  507738.000000   507738.000000   507738.000000
# unique            NaN            NaN             NaN             NaN
# top               NaN            NaN             NaN             NaN
# freq              NaN            NaN             NaN             NaN
# mean       331.250143     335.278646      331.464391      334.243921
# std        125.596338     129.200753      129.353404      134.293177
# min         54.000000      23.000000       35.000000       17.000000
# 25%        211.618877     218.881433      211.845849      208.543972
# 50%        351.253515     358.677518      348.005436      346.671118
# 75%        450.738161     449.826209      443.011136      462.314209
# max        555.793921     559.419632      559.118217      569.425169
#
#                attack
# count   507738.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         0.027650
# std          0.163968
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
#
# [11 rows x 31 columns]

# %% [markdown]
# ### Test Data

# %%
df_testdata = pd.read_csv('calms21_tab_data_test.csv') #check for the location of this file in your scenario
df_testdata.describe(include='all')
# Out:
#            Unnamed: 0                              sequence          frame  \
# count   262107.000000                                262107  262107.000000
# unique            NaN                                    19            NaN
# top               NaN  task1/test/mouse071_task1_annotator1            NaN
# freq              NaN                                 23810            NaN
# mean    131053.000000                                   NaN    8263.261538
# std      75663.917841                                   NaN    5641.328436
# min          0.000000                                   NaN       0.000000
# 25%      65526.500000                                   NaN    3448.000000
# 50%     131053.000000                                   NaN    7308.000000
# 75%     196579.500000                                   NaN   12721.000000
# max     262106.000000                                   NaN   23809.000000
#
#                                            id          label      m1_x_nose  \
# count                                  262107  262107.000000  262107.000000
# unique                                 262107            NaN            NaN
# top     task1/test/mouse071_task1_annotator10            NaN            NaN
# freq                                        1            NaN            NaN
# mean                                      NaN       2.266376     513.939727
# std                                       NaN       0.975756     278.254556
# min                                       NaN       0.000000       5.000000
# 25%                                       NaN       1.000000     241.028380
# 50%                                       NaN       3.000000     535.528748
# 75%                                       NaN       3.000000     783.145581
# max                                       NaN       3.000000    1018.580750
#
#         m1_x_left_ear  m1_x_right_ear      m1_x_neck  m1_x_left_hip  ...  \
# count   262107.000000   262107.000000  262107.000000  262107.000000  ...
# unique            NaN             NaN            NaN            NaN  ...
# top               NaN             NaN            NaN            NaN  ...
# freq              NaN             NaN            NaN            NaN  ...
# mean       507.959238      514.128108     510.463338     503.591579  ...
# std        268.973177      272.349489     267.655132     257.437620  ...
# min         33.000000       31.000000      60.000000      29.338055  ...
# 25%        231.789098      233.545021     229.809164     244.013318  ...
# 50%        529.036261      540.704489     537.097162     541.603241  ...
# 75%        772.883908      783.578070     777.020306     748.865656  ...
# max       1004.090576      994.565234     971.090576     969.342700  ...
#
#         m2_x_right_hip  m2_x_tail_base      m2_y_nose  m2_y_left_ear  \
# count    262107.000000   262107.000000  262107.000000  262107.000000
# unique             NaN             NaN            NaN            NaN
# top                NaN             NaN            NaN            NaN
# freq               NaN             NaN            NaN            NaN
# mean        525.825589      526.462032     326.959332     332.926155
# std         266.912463      266.280491     121.315839     120.554808
# min          39.778656       30.000000       0.000000      25.000000
# 25%         259.500317      273.443821     234.008868     237.490275
# 50%         566.178772      563.410327     344.284080     357.869996
# 75%         786.856229      770.940503     421.703782     427.041800
# max         984.623553      972.580499     568.409676     560.213153
#
#         m2_y_right_ear      m2_y_neck  m2_y_left_hip  m2_y_right_hip  \
# count    262107.000000  262107.000000  262107.000000   262107.000000
# unique             NaN            NaN            NaN             NaN
# top                NaN            NaN            NaN             NaN
# freq               NaN            NaN            NaN             NaN
# mean        331.034622     333.423909     340.842548      336.891455
# std         119.828277     118.606227     126.279135      123.701674
# min          25.000000      50.000000      29.000000       33.418250
# 25%         228.468046     230.775126     232.939386      220.732922
# 50%         350.107725     359.426131     367.458852      354.292183
# 75%         431.188873     431.796258     448.157663      449.085840
# max         552.390822     553.419516     556.329038      551.034543
#
#         m2_y_tail_base         attack
# count    262107.000000  262107.000000
# unique             NaN            NaN
# top                NaN            NaN
# freq               NaN            NaN
# mean        343.179612       0.048186
# std         131.609569       0.214160
# min          37.000000       0.000000
# 25%         226.052492       0.000000
# 50%         364.921254       0.000000
# 75%         470.286724       0.000000
# max         568.808320       1.000000
#
# [11 rows x 34 columns]

# %%
df_testdata.head(10)
# Out:
#    Unnamed: 0                              sequence  frame  \
# 0           0  task1/test/mouse071_task1_annotator1      0
# 1           1  task1/test/mouse071_task1_annotator1      1
# 2           2  task1/test/mouse071_task1_annotator1      2
# 3           3  task1/test/mouse071_task1_annotator1      3
# 4           4  task1/test/mouse071_task1_annotator1      4
# 5           5  task1/test/mouse071_task1_annotator1      5
# 6           6  task1/test/mouse071_task1_annotator1      6
# 7           7  task1/test/mouse071_task1_annotator1      7
# 8           8  task1/test/mouse071_task1_annotator1      8
# 9           9  task1/test/mouse071_task1_annotator1      9
#
#                                       id  label   m1_x_nose  m1_x_left_ear  \
# 0  task1/test/mouse071_task1_annotator10      3  720.980978     654.980978
# 1  task1/test/mouse071_task1_annotator11      1  733.408734     663.408734
# 2  task1/test/mouse071_task1_annotator12      1  742.879459     670.879459
# 3  task1/test/mouse071_task1_annotator13      1  751.682971     679.682971
# 4  task1/test/mouse071_task1_annotator14      1  754.399670     687.399670
# 5  task1/test/mouse071_task1_annotator15      1  759.532123     687.532123
# 6  task1/test/mouse071_task1_annotator16      1  761.749924     690.749924
# 7  task1/test/mouse071_task1_annotator17      1  768.509235     694.509235
# 8  task1/test/mouse071_task1_annotator18      1  764.960052     691.960052
# 9  task1/test/mouse071_task1_annotator19      1  763.523474     693.523474
#
#    m1_x_right_ear   m1_x_neck  m1_x_left_hip  ...  m2_x_right_hip  \
# 0      698.980978  661.980978     550.980978  ...      830.674377
# 1      705.408734  668.408734     554.408734  ...      832.197046
# 2      708.879459  675.879459     559.879459  ...      833.179437
# 3      714.682971  681.682971     568.682971  ...      835.078973
# 4      722.399670  688.399670     577.399670  ...      834.261469
# 5      732.532123  697.532123     583.532123  ...      831.568384
# 6      733.749924  700.749924     597.749924  ...      832.215430
# 7      738.509235  705.509235     608.509235  ...      830.048016
# 8      738.960052  705.960052     612.960052  ...      833.139728
# 9      740.523474  705.523474     613.523474  ...      835.767688
#
#    m2_x_tail_base   m2_y_nose  m2_y_left_ear  m2_y_right_ear   m2_y_neck  \
# 0      759.674377  485.749376     460.749376      434.749376  437.749376
# 1      761.197046  490.161792     468.161792      438.161792  442.161792
# 2      765.179437  498.969705     471.969705      441.969705  444.969705
# 3      767.078973  499.599931     470.599931      442.599931  442.599931
# 4      769.261469  500.060898     466.060898      436.060898  436.060898
# 5      768.568384  501.523793     457.523793      432.523793  431.523793
# 6      771.215430  505.415578     450.415578      431.415578  428.415578
# 7      772.048016  504.713985     444.713985      431.713985  427.713985
# 8      783.139728  505.219398     444.219398      439.219398  431.219398
# 9      784.767688  507.195563     443.195563      446.195563  435.195563
#
#    m2_y_left_hip  m2_y_right_hip  m2_y_tail_base  attack
# 0     404.749376      348.749376      340.749376       0
# 1     411.161792      355.161792      347.161792       0
# 2     414.969705      359.969705      351.969705       0
# 3     418.599931      362.599931      354.599931       0
# 4     417.060898      363.060898      356.060898       0
# 5     412.523793      359.523793      355.523793       0
# 6     408.415578      360.415578      356.415578       0
# 7     400.713985      363.713985      351.713985       0
# 8     392.219398      368.219398      344.219398       0
# 9     392.195563      378.195563      350.195563       0
#
# [10 rows x 34 columns]

# %%
df_testdata = df_testdata.drop(columns=['Unnamed: 0', 'sequence', 'frame'])
df_testdata.head(1)
# Out:
#                                       id  label   m1_x_nose  m1_x_left_ear  \
# 0  task1/test/mouse071_task1_annotator10      3  720.980978     654.980978
#
#    m1_x_right_ear   m1_x_neck  m1_x_left_hip  m1_x_right_hip  m1_x_tail_base  \
# 0      698.980978  661.980978     550.980978      589.980978      511.980978
#
#     m1_y_nose  ...  m2_x_right_hip  m2_x_tail_base   m2_y_nose  m2_y_left_ear  \
# 0  327.829798  ...      830.674377      759.674377  485.749376     460.749376
#
#    m2_y_right_ear   m2_y_neck  m2_y_left_hip  m2_y_right_hip  m2_y_tail_base  \
# 0      434.749376  437.749376     404.749376      348.749376      340.749376
#
#    attack
# 0       0
#
# [1 rows x 31 columns]

# %%
df_testdata.describe(include='all')
# Out:
#                                            id          label      m1_x_nose  \
# count                                  262107  262107.000000  262107.000000
# unique                                 262107            NaN            NaN
# top     task1/test/mouse071_task1_annotator10            NaN            NaN
# freq                                        1            NaN            NaN
# mean                                      NaN       2.266376     513.939727
# std                                       NaN       0.975756     278.254556
# min                                       NaN       0.000000       5.000000
# 25%                                       NaN       1.000000     241.028380
# 50%                                       NaN       3.000000     535.528748
# 75%                                       NaN       3.000000     783.145581
# max                                       NaN       3.000000    1018.580750
#
#         m1_x_left_ear  m1_x_right_ear      m1_x_neck  m1_x_left_hip  \
# count   262107.000000   262107.000000  262107.000000  262107.000000
# unique            NaN             NaN            NaN            NaN
# top               NaN             NaN            NaN            NaN
# freq              NaN             NaN            NaN            NaN
# mean       507.959238      514.128108     510.463338     503.591579
# std        268.973177      272.349489     267.655132     257.437620
# min         33.000000       31.000000      60.000000      29.338055
# 25%        231.789098      233.545021     229.809164     244.013318
# 50%        529.036261      540.704489     537.097162     541.603241
# 75%        772.883908      783.578070     777.020306     748.865656
# max       1004.090576      994.565234     971.090576     969.342700
#
#         m1_x_right_hip  m1_x_tail_base      m1_y_nose  ...  m2_x_right_hip  \
# count    262107.000000   262107.000000  262107.000000  ...   262107.000000
# unique             NaN             NaN            NaN  ...             NaN
# top                NaN             NaN            NaN  ...             NaN
# freq               NaN             NaN            NaN  ...             NaN
# mean        511.323834      504.367232     306.115237  ...      525.825589
# std         261.276368      252.575332     132.411827  ...      266.912463
# min          34.507401       33.743536       3.000000  ...       39.778656
# 25%         242.883161      256.281390     191.827103  ...      259.500317
# 50%         552.060089      544.719537     308.098150  ...      566.178772
# 75%         758.979282      730.331180     422.022860  ...      786.856229
# max        1003.125427      989.042505     565.857285  ...      984.623553
#
#         m2_x_tail_base      m2_y_nose  m2_y_left_ear  m2_y_right_ear  \
# count    262107.000000  262107.000000  262107.000000   262107.000000
# unique             NaN            NaN            NaN             NaN
# top                NaN            NaN            NaN             NaN
# freq               NaN            NaN            NaN             NaN
# mean        526.462032     326.959332     332.926155      331.034622
# std         266.280491     121.315839     120.554808      119.828277
# min          30.000000       0.000000      25.000000       25.000000
# 25%         273.443821     234.008868     237.490275      228.468046
# 50%         563.410327     344.284080     357.869996      350.107725
# 75%         770.940503     421.703782     427.041800      431.188873
# max         972.580499     568.409676     560.213153      552.390822
#
#             m2_y_neck  m2_y_left_hip  m2_y_right_hip  m2_y_tail_base  \
# count   262107.000000  262107.000000   262107.000000   262107.000000
# unique            NaN            NaN             NaN             NaN
# top               NaN            NaN             NaN             NaN
# freq              NaN            NaN             NaN             NaN
# mean       333.423909     340.842548      336.891455      343.179612
# std        118.606227     126.279135      123.701674      131.609569
# min         50.000000      29.000000       33.418250       37.000000
# 25%        230.775126     232.939386      220.732922      226.052492
# 50%        359.426131     367.458852      354.292183      364.921254
# 75%        431.796258     448.157663      449.085840      470.286724
# max        553.419516     556.329038      551.034543      568.808320
#
#                attack
# count   262107.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         0.048186
# std          0.214160
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
#
# [11 rows x 31 columns]

# %% [markdown]
# ### 1.2. Unbalanced label distribution
# The problem could be a multi label classification to predict all 4 annotated behaviours.
# For a first step we focus on a binary classification problem and just predict attach.
#
# In either case, we can see, that the label to predict is a minority class and we will have to accomodate this in the hyperparameters and in the chosen metrics for evaluation.

# %% [markdown]
# #### Train data

# %%
df_traindata['label'].value_counts()
# Out:
# label
# 3    318469
# 1    146615
# 2     28615
# 0     14039
# Name: count, dtype: int64

# %%
df_traindata['attack'].value_counts()
# Out:
# attack
# 0    493699
# 1     14039
# Name: count, dtype: int64

# %% [markdown]
# #### Test data

# %%
df_testdata['label'].value_counts()
# Out:
# label
# 3    156354
# 1     61275
# 2     31848
# 0     12630
# Name: count, dtype: int64

# %%
df_testdata['attack'].value_counts()
# Out:
# attack
# 0    249477
# 1     12630
# Name: count, dtype: int64

# %% [markdown]
# ## 2 | Data characteristics

# %% [markdown]
# ### 2.1 Data Correlations

# %% [markdown]
# Getting a quick overview of correlations between the different columns.

# %%
df_traindata.corr(numeric_only=True)
# Out:
#                    label  m1_x_nose  m1_x_left_ear  m1_x_right_ear  m1_x_neck  \
# label           1.000000  -0.075369      -0.076983       -0.074854  -0.076243
# m1_x_nose      -0.075369   1.000000       0.987645        0.987697   0.983617
# m1_x_left_ear  -0.076983   0.987645       1.000000        0.990216   0.996500
# m1_x_right_ear -0.074854   0.987697       0.990216        1.000000   0.996595
# m1_x_neck      -0.076243   0.983617       0.996500        0.996595   1.000000
# m1_x_left_hip  -0.074644   0.921389       0.966327        0.954226   0.972185
# m1_x_right_hip -0.071906   0.921539       0.954124        0.966091   0.972100
# m1_x_tail_base -0.070846   0.856943       0.912945        0.913080   0.930804
# m1_y_nose      -0.064691   0.057136       0.035383        0.090421   0.065093
# m1_y_left_ear  -0.072435   0.090621       0.062652        0.084450   0.068501
# m1_y_right_ear -0.069428   0.003435       0.021463        0.042897   0.041290
# m1_y_neck      -0.074687   0.045121       0.045990        0.056690   0.053413
# m1_y_left_hip  -0.075217   0.112833       0.109420        0.068555   0.080903
# m1_y_right_hip -0.070776  -0.046943       0.008470       -0.032205  -0.000609
# m1_y_tail_base -0.072733   0.024290       0.065410       -0.004657   0.031886
# m2_x_nose      -0.004949   0.286814       0.260995        0.261247   0.252514
# m2_x_left_ear  -0.003457   0.278373       0.251487        0.252673   0.243263
# m2_x_right_ear -0.006903   0.280521       0.253589        0.253610   0.244549
# m2_x_neck      -0.004906   0.275849       0.248715        0.249423   0.240052
# m2_x_left_hip   0.000069   0.248559       0.221516        0.222813   0.213115
# m2_x_right_hip -0.003647   0.252900       0.225049        0.226166   0.216205
# m2_x_tail_base  0.001767   0.228973       0.201356        0.203263   0.193026
# m2_y_nose       0.014134   0.066398       0.047568        0.078874   0.062580
# m2_y_left_ear   0.019413   0.078335       0.059832        0.094227   0.077117
# m2_y_right_ear  0.019515   0.052816       0.032135        0.067466   0.049202
# m2_y_neck       0.021374   0.065663       0.045851        0.081652   0.063600
# m2_y_left_hip   0.023343   0.084013       0.067058        0.100654   0.084473
# m2_y_right_hip  0.031464   0.025346       0.007016        0.042367   0.024886
# m2_y_tail_base  0.028882   0.045457       0.029947        0.062398   0.046983
# attack         -0.395764  -0.019784      -0.016054       -0.018937  -0.016659
#
#                 m1_x_left_hip  m1_x_right_hip  m1_x_tail_base  m1_y_nose  \
# label               -0.074644       -0.071906       -0.070846  -0.064691
# m1_x_nose            0.921389        0.921539        0.856943   0.057136
# m1_x_left_ear        0.966327        0.954124        0.912945   0.035383
# m1_x_right_ear       0.954226        0.966091        0.913080   0.090421
# m1_x_neck            0.972185        0.972100        0.930804   0.065093
# m1_x_left_hip        1.000000        0.981617        0.981672   0.028742
# m1_x_right_hip       0.981617        1.000000        0.981831   0.117498
# m1_x_tail_base       0.981672        0.981831        1.000000   0.077503
# m1_y_nose            0.028742        0.117498        0.077503   1.000000
# m1_y_left_ear        0.017462        0.066528        0.021960   0.948661
# m1_y_right_ear       0.060342        0.108695        0.113354   0.949142
# m1_y_neck            0.045119        0.079911        0.067244   0.939624
# m1_y_left_hip        0.058967        0.018326        0.004276   0.707149
# m1_y_right_hip       0.078850        0.038748        0.101222   0.709862
# m1_y_tail_base       0.084852       -0.002557        0.045736   0.536713
# m2_x_nose            0.200630        0.204545        0.160799  -0.010546
# m2_x_left_ear        0.189674        0.194957        0.149588  -0.014707
# m2_x_right_ear       0.190982        0.194509        0.149529  -0.018416
# m2_x_neck            0.186027        0.190590        0.145064  -0.018552
# m2_x_left_hip        0.158784        0.164209        0.118516  -0.027738
# m2_x_right_hip       0.160805        0.165831        0.119468  -0.027684
# m2_x_tail_base       0.137961        0.144079        0.097980  -0.032469
# m2_y_nose            0.034164        0.078650        0.049817   0.287449
# m2_y_left_ear        0.049020        0.098026        0.068566   0.310674
# m2_y_right_ear       0.017631        0.067870        0.035580   0.296926
# m2_y_neck            0.033330        0.084416        0.052919   0.309882
# m2_y_left_hip        0.057875        0.106545        0.078005   0.305367
# m2_y_right_hip      -0.003292        0.047642        0.017949   0.287233
# m2_y_tail_base       0.022647        0.069887        0.043516   0.284447
# attack              -0.010745       -0.014653       -0.009018   0.009689
#
#                 m1_y_left_ear  ...  m2_x_right_hip  m2_x_tail_base  m2_y_nose  \
# label               -0.072435  ...       -0.003647        0.001767   0.014134
# m1_x_nose            0.090621  ...        0.252900        0.228973   0.066398
# m1_x_left_ear        0.062652  ...        0.225049        0.201356   0.047568
# m1_x_right_ear       0.084450  ...        0.226166        0.203263   0.078874
# m1_x_neck            0.068501  ...        0.216205        0.193026   0.062580
# m1_x_left_hip        0.017462  ...        0.160805        0.137961   0.034164
# m1_x_right_hip       0.066528  ...        0.165831        0.144079   0.078650
# m1_x_tail_base       0.021960  ...        0.119468        0.097980   0.049817
# m1_y_nose            0.948661  ...       -0.027684       -0.032469   0.287449
# m1_y_left_ear        1.000000  ...        0.002929       -0.004253   0.246329
# m1_y_right_ear       0.938865  ...       -0.076227       -0.081134   0.233271
# m1_y_neck            0.980213  ...       -0.040492       -0.047375   0.226781
# m1_y_left_hip        0.872987  ...        0.017095        0.006457   0.133226
# m1_y_right_hip       0.792710  ...       -0.113460       -0.121071   0.112450
# m1_y_tail_base       0.704579  ...       -0.057091       -0.067410   0.052619
# m2_x_nose            0.021699  ...        0.934313        0.889040   0.078117
# m2_x_left_ear        0.016375  ...        0.962645        0.936600   0.056036
# m2_x_right_ear       0.014892  ...        0.973280        0.934784   0.097706
# m2_x_neck            0.013452  ...        0.978523        0.950695   0.076397
# m2_x_left_hip        0.002398  ...        0.984049        0.986949   0.039007
# m2_x_right_hip       0.002929  ...        1.000000        0.986457   0.105112
# m2_x_tail_base      -0.004253  ...        0.986457        1.000000   0.069018
# m2_y_nose            0.246329  ...        0.105112        0.069018   1.000000
# m2_y_left_ear        0.263983  ...        0.062401        0.031479   0.947040
# m2_y_right_ear       0.249184  ...        0.128549        0.131193   0.944508
# m2_y_neck            0.261402  ...        0.092105        0.084744   0.934546
# m2_y_left_hip        0.261807  ...        0.044803        0.042178   0.752433
# m2_y_right_hip       0.238766  ...        0.076398        0.124561   0.745279
# m2_y_tail_base       0.241811  ...        0.036244        0.075898   0.624272
# attack               0.013187  ...       -0.034243       -0.032915  -0.018881
#
#                 m2_y_left_ear  m2_y_right_ear  m2_y_neck  m2_y_left_hip  \
# label                0.019413        0.019515   0.021374       0.023343
# m1_x_nose            0.078335        0.052816   0.065663       0.084013
# m1_x_left_ear        0.059832        0.032135   0.045851       0.067058
# m1_x_right_ear       0.094227        0.067466   0.081652       0.100654
# m1_x_neck            0.077117        0.049202   0.063600       0.084473
# m1_x_left_hip        0.049020        0.017631   0.033330       0.057875
# m1_x_right_hip       0.098026        0.067870   0.084416       0.106545
# m1_x_tail_base       0.068566        0.035580   0.052919       0.078005
# m1_y_nose            0.310674        0.296926   0.309882       0.305367
# m1_y_left_ear        0.263983        0.249184   0.261402       0.261807
# m1_y_right_ear       0.254574        0.236371   0.250727       0.254802
# m1_y_neck            0.244944        0.227121   0.240567       0.244101
# m1_y_left_hip        0.138147        0.121610   0.130724       0.135990
# m1_y_right_hip       0.122211        0.099961   0.112288       0.122220
# m1_y_tail_base       0.051797        0.032017   0.040337       0.049526
# m2_x_nose            0.106916        0.064231   0.088163       0.135071
# m2_x_left_ear        0.083629        0.085042   0.092673       0.136640
# m2_x_right_ear       0.086435        0.086911   0.083759       0.086355
# m2_x_neck            0.078536        0.092509   0.088320       0.103983
# m2_x_left_hip        0.037308        0.103247   0.079804       0.090243
# m2_x_right_hip       0.062401        0.128549   0.092105       0.044803
# m2_x_tail_base       0.031479        0.131193   0.084744       0.042178
# m2_y_nose            0.947040        0.944508   0.934546       0.752433
# m2_y_left_ear        1.000000        0.946510   0.982831       0.902521
# m2_y_right_ear       0.946510        1.000000   0.983155       0.842413
# m2_y_neck            0.982831        0.983155   1.000000       0.913505
# m2_y_left_hip        0.902521        0.842413   0.913505       1.000000
# m2_y_right_hip       0.839694        0.899937   0.911666       0.915883
# m2_y_tail_base       0.783701        0.781903   0.836580       0.954623
# attack              -0.020121       -0.015896  -0.017856      -0.019179
#
#                 m2_y_right_hip  m2_y_tail_base    attack
# label                 0.031464        0.028882 -0.395764
# m1_x_nose             0.025346        0.045457 -0.019784
# m1_x_left_ear         0.007016        0.029947 -0.016054
# m1_x_right_ear        0.042367        0.062398 -0.018937
# m1_x_neck             0.024886        0.046983 -0.016659
# m1_x_left_hip        -0.003292        0.022647 -0.010745
# m1_x_right_hip        0.047642        0.069887 -0.014653
# m1_x_tail_base        0.017949        0.043516 -0.009018
# m1_y_nose             0.287233        0.284447  0.009689
# m1_y_left_ear         0.238766        0.241811  0.013187
# m1_y_right_ear        0.232544        0.238316  0.019935
# m1_y_neck             0.219378        0.225742  0.019150
# m1_y_left_hip         0.107303        0.118858  0.019842
# m1_y_right_hip        0.094497        0.109779  0.029858
# m1_y_tail_base        0.020195        0.037262  0.029831
# m2_x_nose             0.034730        0.078972 -0.038408
# m2_x_left_ear         0.084769        0.115239 -0.036842
# m2_x_right_ear        0.032279        0.041805 -0.036953
# m2_x_neck             0.066345        0.078443 -0.036432
# m2_x_left_hip         0.122496        0.115917 -0.034594
# m2_x_right_hip        0.076398        0.036244 -0.034243
# m2_x_tail_base        0.124561        0.075898 -0.032915
# m2_y_nose             0.745279        0.624272 -0.018881
# m2_y_left_ear         0.839694        0.783701 -0.020121
# m2_y_right_ear        0.899937        0.781903 -0.015896
# m2_y_neck             0.911666        0.836580 -0.017856
# m2_y_left_hip         0.915883        0.954623 -0.019179
# m2_y_right_hip        1.000000        0.952622 -0.012511
# m2_y_tail_base        0.952622        1.000000 -0.014315
# attack               -0.012511       -0.014315  1.000000
#
# [30 rows x 30 columns]

# %% [markdown]
# Summary comments on correlations.
# High correlation between same Mouse' nose, ears and neck, a little less for tail.
# It might make sense to reduce the number of features per mouse to nose and tail.

# %% [markdown]
# ## 2.2 Descriptive Statistic

# %% [markdown]
# Add some more details.

# %%
# Train
plt.hist(df_traindata['m1_x_nose'])
plt.show()

plt.hist(df_traindata['m1_y_nose'])
plt.show()

plt.hist(df_traindata['m2_x_nose'])
plt.show()

plt.hist(df_traindata['m2_y_nose'])
plt.show()

plt.hist(df_traindata['attack'])
plt.show()


# Test
plt.hist(df_testdata['m1_x_nose'])
plt.show()

plt.hist(df_testdata['m1_y_nose'])
plt.show()

plt.hist(df_testdata['m2_x_nose'])
plt.show()

plt.hist(df_testdata['m2_y_nose'])
plt.show()

plt.hist(df_testdata['attack'])
plt.show()

# %% [markdown]
# Add some summary on data characteristics.

# %% [markdown]
# ## 3 | Train Test Split

# %% [markdown]
# ### 3.1 Transform dataframe as needed for sklearn
# Using train and test as returned as provided, no split necessary anymore, just the transform to the scikit-learn format

# %% [markdown]
# Sklearn Algorithms are using an X-feature matrix and a y-label vector.

# %%
# Label: attack - binary classification
# Label: label - multi label classification
label = ['attack']
print('Used label: ', label)

# features List
mice = ['m1', 'm2']
coordinates = ['x', 'y']
# for processing time reducing the initial experiment to nose and tail
bodyparts = ['nose', 'tail_base'] #'left_ear', 'right_ear', 'neck', 'left_hip', 'right_hip',

features = []
for m in mice:
    for c in coordinates:
        for b in bodyparts:
            feature = m+'_'+c+'_'+b
            features.append(feature)

#features = ['m1_x_nose', 'm1_y_nose', 'm2_x_nose', 'm2_y_nose']
print('Used features: ', features)
# Out:
# Used label:  ['attack']
# Used features:  ['m1_x_nose', 'm1_x_tail_base', 'm1_y_nose', 'm1_y_tail_base', 'm2_x_nose', 'm2_x_tail_base', 'm2_y_nose', 'm2_y_tail_base']

# %%
y_train = np.ravel(df_traindata[label])
X_train = df_traindata[features]
X_train.columns
# Out:
# Index(['m1_x_nose', 'm1_x_tail_base', 'm1_y_nose', 'm1_y_tail_base',
#        'm2_x_nose', 'm2_x_tail_base', 'm2_y_nose', 'm2_y_tail_base'],
#       dtype='object')

# %%
y_test = np.ravel(df_testdata[label])
X_test = df_testdata[features]
X_test.columns
# Out:
# Index(['m1_x_nose', 'm1_x_tail_base', 'm1_y_nose', 'm1_y_tail_base',
#        'm2_x_nose', 'm2_x_tail_base', 'm2_y_nose', 'm2_y_tail_base'],
#       dtype='object')

# %% [markdown]
# ### 3.2 Train Test Split

# %% [markdown]
# not needed anymore, as train/test is given by the dataset and for learning cross validation will be used
# Learning with 70% Train data, holding out 30% of the data.

# %% [markdown]
# ## 3.2 Compare Train/Test
# Checking if label and features are similarily distributed in both sets.
# In both cases an unbalanced classification problem exist, even so the percentage of 'attack' labels in the test set is higher.

# %%
plt.hist(X_train['m1_x_nose'])
plt.show()

plt.hist(X_test['m1_x_nose'])
plt.show()

plt.hist(y_train)
plt.show()

plt.hist(y_test)
plt.show()

# %% [markdown]
# ## 4 | Metrics for Evaluation

# %% [markdown]
# Selection of the metric is depending on the task, classification method and dataset characteristics.
#
# Classification task is imbalanced (label is minority class). Accuracy can be misleading here.
#
# Thus, the metrics F1 Score weighted and F1 Score will be compared for for the minority classes.

# %%
from sklearn.metrics import f1_score, roc_auc_score, roc_curve

# unbalanciert
# multiclass --> umgewandelt auf binär (Label 0,1)

# to track results a table will be kept

results = []

def evaluate(method, predict, y_test):

    result = []
    f1_score_weighted = f1_score(y_test, predict, average='weighted')
    print('F1 Score weighted is: ', f1_score_weighted)

    f1_score_0 = f1_score(y_test, predict, average=None)[0]
    f1_score_1 = f1_score(y_test, predict, average=None)[1]
    print('F1 Score by Class is: ', f1_score_0, f1_score_1)

    auc = roc_auc_score(y_test, predict)
    print('AUC Score is :', auc)

    # dummy classifier confusion matrix
    ConfusionMatrixDisplay.from_predictions(y_test, predict)
    plt.show()

    result = {'Method': method,
              'DataSet': 'Mouse_simple',
              'AUC': auc,
              'F1_w': f1_score_weighted,
              'F1_0': f1_score_0,
              'F1_1': f1_score_1}

    return result

# %% [markdown]
# Finding a balance of recall and precision:
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
#
# average{‘micro’, ‘macro’, ‘samples’, ‘weighted’, ‘binary’} or None, default=’binary’
# This parameter is required for multiclass/multilabel targets. If None, the scores for each class are returned. Otherwise, this determines the type of averaging performed on the data:
#
# 'binary':
# Only report results for the class specified by pos_label. This is applicable only if targets (y_{true,pred}) are binary.
#
# 'micro':
# Calculate metrics globally by counting the total true positives, false negatives and false positives.
#
# 'macro':
# Calculate metrics for each label, and find their unweighted mean. This does not take label imbalance into account.
#
# 'weighted':
# Calculate metrics for each label, and find their average weighted by support (the number of true instances for each label). This alters ‘macro’ to account for label imbalance; it can result in an F-score that is not between precision and recall.
#
# 'samples':
# Calculate metrics for each instance, and find their average (only meaningful for multilabel classification where this differs from accuracy_score).

# %% [markdown]
# ## 5 | Classification Methods

# %% [markdown]
# ### 5.1 Dummy Classifier
#
# Using a random generator to get a naive baseline and check if the following methods are better than chance.

# %% [markdown]
# class sklearn.dummy.DummyClassifier(*, strategy='prior', random_state=None, constant=None)[source]¶
#
# https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html
#
# strategy{“most_frequent”, “prior”, “stratified”, “uniform”, “constant”}, default=”prior”
#
# “prior”: the predict method always returns the most frequent class label in the observed y argument passed to fit (like “most_frequent”). predict_proba always returns the empirical class distribution of y also known as the empirical class prior distribution.

# %%
# Hier Code einfügen
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy='prior')
dummy_clf.fit(X_train, y_train)
cv_score_mean = cross_val_score(dummy_clf, X_train, y_train, cv=5).mean()
print('Train Dummy Classifier Cross Val Score Mean: ',cv_score_mean)

dummy_predict = dummy_clf.predict(X_test)

result = evaluate('dummy', dummy_predict, y_test)
results.append(result)

pd.DataFrame(results)
# Out:
# Train Dummy Classifier Cross Val Score Mean:  0.9723499127612703
# F1 Score weighted is:  0.9283151724119681
# F1 Score by Class is:  0.9753119722274348 0.0
# AUC Score is : 0.5
#   Method       DataSet  AUC      F1_w      F1_0  F1_1
# 0  dummy  Mouse_simple  0.5  0.928315  0.975312   0.0

# %% [markdown]
# The dummy classifier does not recognize any minority class labels.

# %% [markdown]
# ### 5.2 Baseline
#
# Use a classic but simple method to determine a less naive baseline not only relying on chance..

# %% [markdown]
# ### 5.2.1 Logistic Regression

# %% [markdown]
# class sklearn.linear_model.LogisticRegression(penalty='l2', *, dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# class_weightdict or ‘balanced’, default=None

# %%
# Hier Code einfügen
from sklearn.linear_model import LogisticRegression

lr_clf = LogisticRegression(max_iter=1000, class_weight='balanced')
lr_clf.fit(X_train, y_train)
# needs to be checked with classweights to be fair?

cv_score_mean = cross_val_score(lr_clf, X_train, y_train, cv=5).mean()
print('Logistic Regression Cross Val Score Mean: ',cv_score_mean)

lr_predict = lr_clf.predict(X_test)

result = evaluate('lf', lr_predict, y_test)

results.append(result)

pd.DataFrame(results)
# Out:
# Logistic Regression Cross Val Score Mean:  0.5315203694850432
# F1 Score weighted is:  0.6974161512703376
# F1 Score by Class is:  0.7276116713354328 0.1009721481603019
# AUC Score is : 0.5369719657799651
#   Method       DataSet       AUC      F1_w      F1_0      F1_1
# 0  dummy  Mouse_simple  0.500000  0.928315  0.975312  0.000000
# 1     lf  Mouse_simple  0.536972  0.697416  0.727612  0.100972

# %% [markdown]
# ### 5.2.2 | Random Forest

# %% [markdown]
# class sklearn.ensemble.RandomForestClassifier(n_estimators=100, *, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)[source]¶
#
# class_weight{“balanced”, “balanced_subsample”}, dict or list of dicts, default=None

# %%
# Hier Code einfügen
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(max_depth=2, class_weight='balanced')
rf_clf.fit(X_train, y_train)

cv_score_mean = cross_val_score(rf_clf, X_train, y_train, cv=5).mean()
print('Random Forest Cross Val Score Mean: ',cv_score_mean)

rf_predict = rf_clf.predict(X_test)

result = evaluate('rf', rf_predict, y_test)
results.append(result)

pd.DataFrame(results)
# Out:
# Random Forest Cross Val Score Mean:  0.6155242164304339
# F1 Score weighted is:  0.7310544746904023
# F1 Score by Class is:  0.7605674417468017 0.14809275795807286
# AUC Score is : 0.6490142623022946
#   Method       DataSet       AUC      F1_w      F1_0      F1_1
# 0  dummy  Mouse_simple  0.500000  0.928315  0.975312  0.000000
# 1     lf  Mouse_simple  0.536972  0.697416  0.727612  0.100972
# 2     rf  Mouse_simple  0.649014  0.731054  0.760567  0.148093

# %% [markdown]
# The RF already detects a lot more of the minority classes and also misclassifies less of the majority labels.

# %%
# feature importance
importances = rf_clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in rf_clf.estimators_], axis=0)
forest_importances = pd.Series(importances, index=features)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# ### 5.2.3 Hist Gradient Boosting

# %% [markdown]
# Another statistically motivated method:
#
# https://machinelearningmastery.com/histogram-based-gradient-boosting-ensembles/
# Although gradient boosting performs very well in practice, the models can be slow to train. This is because trees must be created and added sequentially, unlike other ensemble models like random forest where ensemble members can be trained in parallel, exploiting multiple CPU cores. As such, a lot of effort has been put into techniques that improve the efficiency of the gradient boosting training algorithm.
# Instead of finding the split points on the sorted feature values, histogram-based algorithm buckets continuous feature values into discrete bins and uses these bins to construct feature histograms during training. Since the histogram-based algorithm is more efficient in both memory consumption and training speed, we will develop our work on its basis.

# %% [markdown]
# class sklearn.ensemble.HistGradientBoostingClassifier(loss='log_loss', *, learning_rate=0.1, max_iter=100, max_leaf_nodes=31, max_depth=None, min_samples_leaf=20, l2_regularization=0.0, max_bins=255, categorical_features=None, monotonic_cst=None, warm_start=False, early_stopping='auto', scoring='loss', validation_fraction=0.1, n_iter_no_change=10, tol=1e-07, verbose=0, random_state=None)[source]¶

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hgb_clf = HistGradientBoostingClassifier(max_iter=1000, max_depth=2, class_weight='balanced',)
hgb_clf.fit(X_train, y_train)

cv_score_mean = cross_val_score(hgb_clf, X_train, y_train, cv=5).mean()
print('Train HGB Cross Val Score Mean: ', cv_score_mean)

predict = hgb_clf.predict(X_test)

result = evaluate('hgb', predict, y_test)

results.append(result)

pd.DataFrame(results)
# Out:
# Train HGB Cross Val Score Mean:  0.7532407624001938
# F1 Score weighted is:  0.8200910827243949
# F1 Score by Class is:  0.8496557140508848 0.23610885553209757
# AUC Score is : 0.7758261270701824
#   Method       DataSet       AUC      F1_w      F1_0      F1_1
# 0  dummy  Mouse_simple  0.500000  0.928315  0.975312  0.000000
# 1     lf  Mouse_simple  0.536972  0.697416  0.727612  0.100972
# 2     rf  Mouse_simple  0.649014  0.731054  0.760567  0.148093
# 3    hgb  Mouse_simple  0.775826  0.820091  0.849656  0.236109

# %% [markdown]
# HGB has shown an improvement in detection of the minority class
# Initial hyperparameter tuning is attempted for Random Forest and HGB now.

# %% [markdown]
# ## 6 |Optimising hyperparameters for the most promising method

# %%
params = {'max_iter': [1000],
          'max_depth': [4, 8, ],
          'max_leaf_nodes': [15, 30, ],
          #'min_leaf_nodes': [3, ],
          'class_weight': ['balanced'],
          'random_state' : [1234],
 }

#instantiate the gridsearch
hgb_grid = GridSearchCV(hgb_clf, params, n_jobs=5,
 cv=5, scoring={"AUC": "roc_auc"},
 verbose=2, refit="AUC", return_train_score=True)

#fit on the grid
hgb_grid.fit(X_train, y_train)
print(hgb_grid.best_estimator_)

cv_results = hgb_grid.cv_results_
cv_results
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# HistGradientBoostingClassifier(class_weight='balanced', max_depth=4,
#                                max_iter=1000, max_leaf_nodes=30,
#                                random_state=1234)
# {'mean_fit_time': array([38.88726296, 31.41306543, 36.40823164, 24.03628035]),
#  'std_fit_time': array([2.39928313, 5.37632622, 3.30314397, 3.41263827]),
#  'mean_score_time': array([3.80031085, 3.22508221, 3.18290281, 2.04661345]),
#  'std_score_time': array([0.18219647, 0.60997039, 0.34299302, 0.27324854]),
#  'param_class_weight': masked_array(data=['balanced', 'balanced', 'balanced', 'balanced'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[4, 4, 8, 8],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_iter': masked_array(data=[1000, 1000, 1000, 1000],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_leaf_nodes': masked_array(data=[15, 30, 15, 30],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_random_state': masked_array(data=[1234, 1234, 1234, 1234],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'class_weight': 'balanced',
#    'max_depth': 4,
#    'max_iter': 1000,
#    'max_leaf_nodes': 15,
#    'random_state': 1234},
#   {'class_weight': 'balanced',
#    'max_depth': 4,
#    'max_iter': 1000,
#    'max_leaf_nodes': 30,
#    'random_state': 1234},
#   {'class_weight': 'balanced',
#    'max_depth': 8,
#    'max_iter': 1000,
#    'max_leaf_nodes': 15,
#    'random_state': 1234},
#   {'class_weight': 'balanced',
#    'max_depth': 8,
#    'max_iter': 1000,
#    'max_leaf_nodes': 30,
#    'random_state': 1234}],
#  'split0_test_AUC': array([0.85483528, 0.85745954, 0.85419864, 0.85396453]),
#  'split1_test_AUC': array([0.88825412, 0.88921984, 0.87908927, 0.87899385]),
#  'split2_test_AUC': array([0.81136932, 0.81003822, 0.81637097, 0.8224933 ]),
#  'split3_test_AUC': array([0.85595922, 0.85741914, 0.85699982, 0.85568496]),
#  'split4_test_AUC': array([0.86532231, 0.86432347, 0.86200292, 0.86296732]),
#  'mean_test_AUC': array([0.85514805, 0.85569204, 0.85373232, 0.85482079]),
#  'std_test_AUC': array([0.02496742, 0.02564759, 0.02058224, 0.01842416]),
#  'rank_test_AUC': array([2, 1, 4, 3]),
#  'split0_train_AUC': array([0.97846648, 0.97292599, 0.98995844, 0.99219751]),
#  'split1_train_AUC': array([0.97766576, 0.97311337, 0.98793968, 0.99143296]),
#  'split2_train_AUC': array([0.98274102, 0.97144658, 0.98725034, 0.99237035]),
#  'split3_train_AUC': array([0.97951688, 0.97443111, 0.98923614, 0.99406763]),
#  'split4_train_AUC': array([0.9799114 , 0.9828431 , 0.99176228, 0.99259085]),
#  'mean_train_AUC': array([0.97966031, 0.97495203, 0.98922938, 0.99253186]),
#  'std_train_AUC': array([0.00173077, 0.00405744, 0.00158285, 0.00086111])}

# %%
mean_train_AUC = cv_results['mean_train_AUC']
print('HGB Train Grid Cross Val Score Mean ', mean_train_AUC)

mean_test_AUC = cv_results['mean_test_AUC']
print('HGB Test Grid Cross Val Score Mean ', mean_test_AUC)

predict = hgb_grid.predict(X_test)

result = evaluate('hgb_grid', predict, y_test)

results.append(result)

pd.DataFrame(results)
# Out:
# HGB Train Grid Cross Val Score Mean  [0.97966031 0.97495203 0.98922938 0.99253186]
# HGB Test Grid Cross Val Score Mean  [0.85514805 0.85569204 0.85373232 0.85482079]
# F1 Score weighted is:  0.8557614068852964
# F1 Score by Class is:  0.8862469745366452 0.25358817165524705
# AUC Score is : 0.7519701429166538
#      Method       DataSet       AUC      F1_w      F1_0      F1_1
# 0     dummy  Mouse_simple  0.500000  0.928315  0.975312  0.000000
# 1        lf  Mouse_simple  0.536972  0.697416  0.727612  0.100972
# 2        rf  Mouse_simple  0.649014  0.731054  0.760567  0.148093
# 3       hgb  Mouse_simple  0.775826  0.820091  0.849656  0.236109
# 4  hgb_grid  Mouse_simple  0.751970  0.855761  0.886247  0.253588

# %%
params = {'n_estimators': [150],
          'max_depth': [4, 8, ],
          'max_leaf_nodes': [15, 30, ],
          #'min_leaf_nodes': [3, ],
          'class_weight': ['balanced'],
          'random_state' : [1234],
 }

#instantiate the gridsearch
rf_grid = GridSearchCV(rf_clf, params, n_jobs=5,
 cv=5, scoring={"AUC": "roc_auc", "f1": "f1"},
 verbose=2, refit="AUC", return_train_score=True)

#fit on the grid
rf_grid.fit(X_train, y_train)
print(rf_grid.best_estimator_)

cv_results = rf_grid.cv_results_
cv_results
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# RandomForestClassifier(class_weight='balanced', max_depth=8, max_leaf_nodes=30,
#                        n_estimators=150, random_state=1234)
# {'mean_fit_time': array([115.71834378, 114.29112668, 148.20022283, 172.29770274]),
#  'std_fit_time': array([0.89151298, 0.69368009, 1.47136315, 1.29209466]),
#  'mean_score_time': array([1.34406047, 1.3701818 , 1.30960956, 1.39764652]),
#  'std_score_time': array([0.07529007, 0.04755274, 0.0650265 , 0.05576533]),
#  'param_class_weight': masked_array(data=['balanced', 'balanced', 'balanced', 'balanced'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[4, 4, 8, 8],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_leaf_nodes': masked_array(data=[15, 30, 15, 30],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[150, 150, 150, 150],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_random_state': masked_array(data=[1234, 1234, 1234, 1234],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'class_weight': 'balanced',
#    'max_depth': 4,
#    'max_leaf_nodes': 15,
#    'n_estimators': 150,
#    'random_state': 1234},
#   {'class_weight': 'balanced',
#    'max_depth': 4,
#    'max_leaf_nodes': 30,
#    'n_estimators': 150,
#    'random_state': 1234},
#   {'class_weight': 'balanced',
#    'max_depth': 8,
#    'max_leaf_nodes': 15,
#    'n_estimators': 150,
#    'random_state': 1234},
#   {'class_weight': 'balanced',
#    'max_depth': 8,
#    'max_leaf_nodes': 30,
#    'n_estimators': 150,
#    'random_state': 1234}],
#  'split0_test_AUC': array([0.79361853, 0.79356148, 0.80866867, 0.82297045]),
#  'split1_test_AUC': array([0.78843937, 0.78852953, 0.81462298, 0.83963832]),
#  'split2_test_AUC': array([0.78531839, 0.78534977, 0.79039402, 0.7952957 ]),
#  'split3_test_AUC': array([0.83944945, 0.83950796, 0.84371749, 0.85047467]),
#  'split4_test_AUC': array([0.7670922 , 0.76715164, 0.78678918, 0.80518696]),
#  'mean_test_AUC': array([0.79478359, 0.79482008, 0.80883847, 0.82271322]),
#  'std_test_AUC': array([0.02405431, 0.02405573, 0.02037844, 0.02057238]),
#  'rank_test_AUC': array([4, 3, 2, 1]),
#  'split0_train_AUC': array([0.84479839, 0.8449152 , 0.85888006, 0.88145226]),
#  'split1_train_AUC': array([0.83258161, 0.83269101, 0.84685371, 0.86986109]),
#  'split2_train_AUC': array([0.85574695, 0.85583993, 0.86671652, 0.89233556]),
#  'split3_train_AUC': array([0.84465538, 0.84473302, 0.85910965, 0.8804546 ]),
#  'split4_train_AUC': array([0.85003405, 0.85010959, 0.86409389, 0.88623842]),
#  'mean_train_AUC': array([0.84556327, 0.84565775, 0.85913077, 0.88206839]),
#  'std_train_AUC': array([0.00766326, 0.00765557, 0.00682592, 0.00741358]),
#  'split0_test_f1': array([0.11916617, 0.11916291, 0.1313306 , 0.13999103]),
#  'split1_test_f1': array([0.09553014, 0.09546434, 0.12408832, 0.14478179]),
#  'split2_test_f1': array([0.09488824, 0.09483492, 0.09955312, 0.10435062]),
#  'split3_test_f1': array([0.12067562, 0.12066204, 0.13032866, 0.13816063]),
#  'split4_test_f1': array([0.1035634 , 0.10360999, 0.11340507, 0.11728745]),
#  'mean_test_f1': array([0.10676471, 0.10674684, 0.11974115, 0.1289143 ]),
#  'std_test_f1': array([0.01117877, 0.01119661, 0.01194162, 0.0154824 ]),
#  'rank_test_f1': array([3, 4, 2, 1]),
#  'split0_train_f1': array([0.12874805, 0.12873893, 0.14210491, 0.15418279]),
#  'split1_train_f1': array([0.12551402, 0.12551909, 0.13552049, 0.14725283]),
#  'split2_train_f1': array([0.1354663 , 0.13547881, 0.14805785, 0.16262812]),
#  'split3_train_f1': array([0.1247268 , 0.12467961, 0.14238466, 0.15371401]),
#  'split4_train_f1': array([0.13522358, 0.13517187, 0.15677073, 0.16745287]),
#  'mean_train_f1': array([0.12993575, 0.12991766, 0.14496773, 0.15704613]),
#  'std_train_f1': array([0.0046183 , 0.00461968, 0.00711306, 0.0071368 ])}

# %%
mean_train_AUC = cv_results['mean_train_AUC']
print('RF Train Grid Cross Val Score Mean ', mean_train_AUC)

mean_test_AUC = cv_results['mean_test_AUC']
print('RF Test Grid Cross Val Score Mean ', mean_test_AUC)

predict = rf_grid.predict(X_test)

result = evaluate('rf_grid', predict, y_test)

results.append(result)

pd.DataFrame(results)
# Out:
# RF Train Grid Cross Val Score Mean  [0.84556327 0.84565775 0.85913077 0.88206839]
# RF Test Grid Cross Val Score Mean  [0.79478359 0.79482008 0.80883847 0.82271322]
# F1 Score weighted is:  0.7923698030900396
# F1 Score by Class is:  0.8220857176877657 0.20539931804673567
# AUC Score is : 0.742753146470778
#      Method       DataSet       AUC      F1_w      F1_0      F1_1
# 0     dummy  Mouse_simple  0.500000  0.928315  0.975312  0.000000
# 1        lf  Mouse_simple  0.536972  0.697416  0.727612  0.100972
# 2        rf  Mouse_simple  0.649014  0.731054  0.760567  0.148093
# 3       hgb  Mouse_simple  0.775826  0.820091  0.849656  0.236109
# 4  hgb_grid  Mouse_simple  0.751970  0.855761  0.886247  0.253588
# 5   rf_grid  Mouse_simple  0.742753  0.792370  0.822086  0.205399

# %% [markdown]
# Summary of Grid Search with optimized parameter selection:
# The initial selection of the parameter grid is rather small due to time and resource constraints.
#
# For Random forest some improvement AUC and F1 after hyperparameter search could be observed.
# For HGB, no improvement has been observed, but not many parameters have been tried.

# %% [markdown]
# ### 7 Summary

# %% [markdown]
# It can be shown, that several ML methods can detect a correlation between mouse data.
# The naive approach to hyperparameter optimization has not yet improved the run with the default parameters. More time and resources would need to be spend to understand to what extend the results can be further improved.

# %%
pd.DataFrame(results)
# Out:
#      Method       DataSet       AUC      F1_w      F1_0      F1_1
# 0     dummy  Mouse_simple  0.500000  0.928315  0.975312  0.000000
# 1        lf  Mouse_simple  0.536972  0.697416  0.727612  0.100972
# 2        rf  Mouse_simple  0.649014  0.731054  0.760567  0.148093
# 3       hgb  Mouse_simple  0.775826  0.820091  0.849656  0.236109
# 4  hgb_grid  Mouse_simple  0.751970  0.855761  0.886247  0.253588
# 5   rf_grid  Mouse_simple  0.742753  0.792370  0.822086  0.205399

# %% [markdown]
# Summary and next steps
#
# Questioning / evaluating these results.
#
# - Would we want to use this approach for automated annotation?
# - Is AUC or F1 score a valid measure for evaluation?
# - What would be our minimum required AUC/F1 score for using the automatic annotation
#
# - Visualizing some false positives
# - Visualizing some false negatives
